# %% [markdown]
# # Import packages

# %%
# Reading/Writing Data
import os
import glob
import numpy as np
import math 

# Pytorch
import torch 
from torch.utils.data import Subset, DataLoader

# Self-Defined Package
from SMAPDataset import SMAPDataset
from SMCNN import SMCNN
from SDLoss import self_defined_loss
from Preprocessing import random_spatial_sequence, collate_fn

# %% [markdown]
# # Some Utility Functions

# %%
def same_seed(seed): 
    '''Fixes random number generator seeds for reproducibility.'''
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)

# %% [markdown]
# # Training Loop

# %% [markdown]
# # Configurations
# `config` contains hyper-parameters for training and the path to save your model.

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
config = {
    'seed': 5201314,      # Your seed number, you can pick your lucky number. :)
    'is_train': True,
    'test_ratio': 0.2,
    'valid_ratio': 0.1,   # validation_size = train_size * valid_ratio
    'n_epochs': 5000,     # Number of epochs.            
    'train_batch_size': 50, 
    'valid_batch_size': 56,
    'test_batch_size': 1,
    'eds_lambda': 10,
    'learning_rate': 1e-4,
    'step_size': 15,
    'gamma': 0.5,
    'momentum': 0.9,
    'early_stop': 100,    # If model has not improved for this many consecutive epochs, stop training.     
    'root': 'D:\\1GRADUATED\\paper\\downscaling_data\\Soil_moisture_downscale_czt\\DATASET\\SD\\'
}

# %% [markdown]
# # Dataloader
# Read data from files and set up training, validation, and testing sets.

# %%
# # Set seed for reproducibility
same_seed(config['seed'])

# %% [markdown]
# ##### 考虑到需要获取空间上均匀分布的站点数据，所以在每帧中随即挑选站点作为训练集，其余的作为验证集和测试集。因此使用一个字典来保存每天被筛选出来的站点list

# %%
train_sequence = {}
valid_sequence = {}
test_sequence = {}
s2s_dir = config['root'] + 'LABEL\\SMAPID2INSITUID'
subdir_list = sorted(os.listdir(s2s_dir))

# 遍历指定路径下的所有子目录
for subdir in subdir_list:
    subdir_path = os.path.join(s2s_dir, subdir)
    if os.path.isdir(subdir_path):
        # 如果子目录是目录而不是文件，则将子目录加入字典
        full_spatial_sequence_smap = sorted([int(f.split('.')[0]) for f in os.listdir(subdir_path) if f.endswith('.npy')]) # !!!! read out of order
        print(len(full_spatial_sequence_smap), 'of Full Spatial Sequence for', subdir, ':')
        print(full_spatial_sequence_smap)
        
        # Split the train\valid\test dataset by spatial dimension
        train_sequence[subdir], test_sequence[subdir] = random_spatial_sequence(1-config['test_ratio'], full_spatial_sequence_smap)
        train_sequence[subdir], valid_sequence[subdir] = random_spatial_sequence(1-config['valid_ratio'], train_sequence[subdir])
# Out:
# 10 of Full Spatial Sequence for 2015104 :
# [9, 15, 17, 18, 20, 26, 29, 31, 40, 43]
# **************************Data Spliting***************************
# Spliting Rate:  0.8
# 8 of Dataset1:  [15 31 18 40 29 17 43 26]
# 2 of Dataset2:  [ 9 20]
# **************************Data Spliting***************************
# **************************Data Spliting***************************
# Spliting Rate:  0.9
# 7 of Dataset1:  [17 18 29 43 40 26 15]
# 1 of Dataset2:  [31]
# **************************Data Spliting***************************
# 6 of Full Spatial Sequence for 2015106 :
# [15, 16, 20, 26, 27, 29]
# **************************Data Spliting***************************
# Spliting Rate:  0.8
# 4 of Dataset1:  [16 26 20 27]
# 2 of Dataset2:  [15 29]
# **************************Data Spliting***************************
# **************************Data Spliting***************************
# Spliting Rate:  0.9
# 3 of Dataset1:  [27 26 16]
# 1 of Dataset2:  [20]
# **************************Data Spliting***************************
# 4 of Full Spatial Sequence for 2015114 :
# [9, 33, 44, 51]
# **************************Data Spliting***************************
# Spliting Rate:  0.8
# 3 of Dataset1:  [51  9 44]
# 1 of Dataset2:  [33]
# **************************Data Spliting***************************
# **************************Data Spliting***************************
# Spliting Rate:  0.9
# 2 of Dataset1:  [44  9]
# 1 of Dataset2:  [51]
# **************************Data Spliting***************************
# 14 of Full Spatial Sequence for 2015115 :
# [15, 16, 17, 18, 20, 26, 29, 31, 32, 33, 40, 41, 43, 44]
# **************************Data Spliting***************************
# Spliting Rate:  0.8
# 11 of Dataset1:  [40 20 17 29 26 41 44 16 43 18 31]
# 3 of Dataset2:  [15 32 33]
# **************************Data Spliting***************************
# **************************Data Spliting***************************
# Spliting Rate:  0.9
# 9 of Dataset1:  [20 41 40 43 44 26 29 18 17]
# 2 of Dataset2:  [16 31]
# **************************Data Spliting***************************
# 5 of Full Spatial Sequence for 2015117 :
# [16, 31, 32, 33, 44]
# **************************Data Spliting***************************
# Spliting Rate:  0.8
# 4 of Dataset1:  [16 32 31 33]
# 1 of Dataset2:  [44]
# **************************Data Spliting***************************
# **************************Data Spliting***************************
# Spliting Rate:  0.9
# 3 of Dataset1:  [32 16 33]
# 1 of Dataset2:  [31]
# **************************Data Spliting***************************
# 2 of Full Spatial Sequence for 2015130 :
# [16, 29]
# **************************Data Spliting***************************
# Spliting Rate:  0.8
# 1 of Dataset1:  [29]
# 1 of Dataset2:  [16]
# **************************Data Spliting***************************
# **************************Data Spliting***************************
# Spliting Rate:  0.9
# 0 of Dataset1:  []
# 1 of Dataset2:  [29]
# **************************Data Spliting***************************
# 19 of Full Spatial Sequence for 2015131 :
# [9, 10, 15, 16, 17, 18, 20, 26, 27, 29, 31, 32, 33, 40, 41, 43, 44, 45, 51]
# **************************Data Spliting***************************
# Spliting Rate:  0.8
# 15 of Dataset1:  [20 26 31 43 44 40 33 18 16 51 29 27 41 45 10]
# 4 of Dataset2:  [ 9 15 17 32]
# **************************Data Spliting***************************
# **************************Data Spliting***************************
# Spliting Rate:  0.9
# 13 of Dataset1:  [31 26 43 29 16 41 10 33 40 44 51 45 18]
# 2 of Dataset2:  [20 27]
# **************************Data Spliting***************************
# 1 of Full Spatial Sequence for 2015136 :
# [15]
# **************************Data Spliting***************************
# Spliting Rate:  0.8
# 0 of Dataset1:  []
# 1 of Dataset2:  [15]
# **************************Data Spliting***************************
# **************************Data Spliting***************************
# Spliting Rate:  0.9
# 0 of Dataset1:  []
# 0 of Dataset2:  []
# **************************Data Spliting***************************
# 2 of Full Spatial Sequence for 2015138 :
# [26, 27]
# **************************Data Spliting***************************
# Spliting Rate:  0.8
# 1 of Dataset1:  [26]
# 1 of Dataset2:  [27]
# **************************Data Spliting***************************
# **************************Data Spliting***************************
# Spliting Rate:  0.9
# 0 of Dataset1:  []
# 1 of Dataset2:  [26]
# **************************Data Spliting***************************
# 11 of Full Spatial Sequence for 2015149 :
# [15, 16, 17, 20, 26, 27, 29, 31, 32, 40, 41]
# **************************Data Spliting***************************
# Spliting Rate:  0.8
# 8 of Dataset1:  [15 20 29 31 40 27 32 16]
# 3 of Dataset2:  [17 26 41]
# **************************Data Spliting***************************
# **************************Data Spliting***************************
# Spliting Rate:  0.9
# 7 of Dataset1:  [27 32 20 16 40 29 31]
# 1 of Dataset2:  [15]
# **************************Data Spliting***************************
# 1 of Full Spatial Sequence for 2015160 :
# [17]
# **************************Data Spliting***************************
# Spliting Rate:  0.8
# 0 of Dataset1:  []
# 1 of Dataset2:  [17]
# **************************Data Spliting***************************
# **************************Data Spliting***************************
# Spliting Rate:  0.9
# 0 of Dataset1:  []
# 0 of Dataset2:  []
# **************************Data Spliting***************************
# 7 of Full Spatial Sequence for 2015162 :
# [15, 16, 17, 26, 27, 31, 40]
# **************************Data Spliting***************************
# Spliting Rate:  0.8
# 5 of Dataset1:  [26 40 17 15 31]
# 2 of Dataset2:  [16 27]
# **************************Data Spliting***************************
# **************************Data Spliting***************************
# Spliting Rate:  0.9
# 4 of Dataset1:  [40 26 31 17]
# 1 of Dataset2:  [15]
# **************************Data Spliting***************************
# 12 of Full Spatial Sequence for 2015165 :
# [9, 10, 16, 17, 18, 20, 31, 32, 33, 40, 44, 45]
# **************************Data Spliting***************************
# Spliting Rate:  0.8
# 9 of Dataset1:  [10 44 16 17 32  9 20 45 40]
# 3 of Dataset2:  [18 31 33]
# **************************Data Spliting***************************
# **************************Data Spliting***************************
# Spliting Rate:  0.9
# 8 of Dataset1:  [16 44 45 40 10  9 32 17]
# 1 of Dataset2:  [20]
# **************************Data Spliting***************************
# 10 of Full Spatial Sequence for 2015171 :
# [20, 29, 31, 32, 33, 41, 43, 44, 45, 51]
# **************************Data Spliting***************************
# Spliting Rate:  0.8
# 8 of Dataset1:  [44 41 33 45 20 43 31 29]
# 2 of Dataset2:  [32 51]
# **************************Data Spliting***************************
# **************************Data Spliting***************************
# Spliting Rate:  0.9
# 7 of Dataset1:  [33 41 20 43 29 44 31]
# 1 of Dataset2:  [45]
# **************************Data Spliting***************************
# 14 of Full Spatial Sequence for 2015176 :
# [9, 10, 15, 17, 18, 20, 26, 31, 32, 33, 40, 41, 43, 44]
# **************************Data Spliting***************************
# Spliting Rate:  0.8
# 11 of Dataset1:  [43 44 10 17 15 18 41 20 40 33 32]
# 3 of Dataset2:  [ 9 26 31]
# **************************Data Spliting***************************
# **************************Data Spliting***************************
# Spliting Rate:  0.9
# 9 of Dataset1:  [17 10 18 32 20 43 40 33 44]
# 2 of Dataset2:  [15 41]
# **************************Data Spliting***************************
# 18 of Full Spatial Sequence for 2015186 :
# [9, 10, 15, 16, 17, 18, 20, 26, 27, 29, 31, 32, 33, 40, 41, 43, 44, 51]
# **************************Data Spliting***************************
# Spliting Rate:  0.8
# 14 of Dataset1:  [51 41 33 27 18 29 17 44 15  9 43 40 31 32]
# 4 of Dataset2:  [10 16 20 26]
# **************************Data Spliting***************************
# **************************Data Spliting***************************
# Spliting Rate:  0.9
# 12 of Dataset1:  [44 27 51 18  9 29 31 17 15 41 33 32]
# 2 of Dataset2:  [40 43]
# **************************Data Spliting***************************
# 14 of Full Spatial Sequence for 2015187 :
# [9, 10, 15, 16, 17, 18, 20, 26, 27, 29, 43, 44, 45, 51]
# **************************Data Spliting***************************
# Spliting Rate:  0.8
# 11 of Dataset1:  [51 29 26 27 43 15  9 20 17 10 45]
# 3 of Dataset2:  [16 18 44]
# **************************Data Spliting***************************
# **************************Data Spliting***************************
# Spliting Rate:  0.9
# 9 of Dataset1:  [26 15 51 43 27 45 20 17 29]
# 2 of Dataset2:  [ 9 10]
# **************************Data Spliting***************************
# 3 of Full Spatial Sequence for 2015194 :
# [9, 10, 26]
# **************************Data Spliting***************************
# Spliting Rate:  0.8
# 2 of Dataset1:  [ 9 10]
# 1 of Dataset2:  [26]
# **************************Data Spliting***************************
# **************************Data Spliting***************************
# Spliting Rate:  0.9
# 1 of Dataset1:  [9]
# 1 of Dataset2:  [10]
# **************************Data Spliting***************************
# 4 of Full Spatial Sequence for 2015195 :
# [10, 29, 31, 40]
# **************************Data Spliting***************************
# Spliting Rate:  0.8
# 3 of Dataset1:  [29 40 10]
# 1 of Dataset2:  [31]
# **************************Data Spliting***************************
# **************************Data Spliting***************************
# Spliting Rate:  0.9
# 2 of Dataset1:  [29 40]
# 1 of Dataset2:  [10]
# **************************Data Spliting***************************
# 6 of Full Spatial Sequence for 2015200 :
# [15, 16, 27, 29, 40, 43]
# **************************Data Spliting***************************
# Spliting Rate:  0.8
# 4 of Dataset1:  [27 40 16 43]
# 2 of Dataset2:  [15 29]
# **************************Data Spliting***************************
# **************************Data Spliting***************************
# Spliting Rate:  0.9
# 3 of Dataset1:  [43 27 40]
# 1 of Dataset2:  [16]
# **************************Data Spliting***************************
# 1 of Full Spatial Sequence for 2015202 :
# [9]
# **************************Data Spliting***************************
# Spliting Rate:  0.8
# 0 of Dataset1:  []
# 1 of Dataset2:  [9]
# **************************Data Spliting***************************
# **************************Data Spliting***************************
# Spliting Rate:  0.9
# 0 of Dataset1:  []
# 0 of Dataset2:  []
# **************************Data Spliting***************************
# 4 of Full Spatial Sequence for 2015203 :
# [16, 17, 26, 33]
# **************************Data Spliting***************************
# Spliting Rate:  0.8
# 3 of Dataset1:  [33 26 17]
# 1 of Dataset2:  [16]
# **************************Data Spliting***************************
# **************************Data Spliting***************************
# Spliting Rate:  0.9
# 2 of Dataset1:  [17 33]
# 1 of Dataset2:  [26]
# **************************Data Spliting***************************
# 7 of Full Spatial Sequence for 2015205 :
# [10, 18, 27, 43, 44, 45, 51]
# **************************Data Spliting***************************
# Spliting Rate:  0.8
# 5 of Dataset1:  [27 18 44 10 45]
# 2 of Dataset2:  [43 51]
# **************************Data Spliting***************************
# **************************Data Spliting***************************
# Spliting Rate:  0.9
# 4 of Dataset1:  [45 44 27 18]
# 1 of Dataset2:  [10]
# **************************Data Spliting***************************
# 3 of Full Spatial Sequence for 2015208 :
# [9, 10, 18]
# **************************Data Spliting***************************
# Spliting Rate:  0.8
# 2 of Dataset1:  [10 18]
# 1 of Dataset2:  [9]
# **************************Data Spliting***************************
# **************************Data Spliting***************************
# Spliting Rate:  0.9
# 1 of Dataset1:  [18]
# 1 of Dataset2:  [10]
# **************************Data Spliting***************************
# 5 of Full Spatial Sequence for 2015211 :
# [10, 20, 44, 45, 51]
# **************************Data Spliting***************************
# Spliting Rate:  0.8
# 4 of Dataset1:  [20 44 45 51]
# 1 of Dataset2:  [10]
# **************************Data Spliting***************************
# **************************Data Spliting***************************
# Spliting Rate:  0.9
# 3 of Dataset1:  [45 44 51]
# 1 of Dataset2:  [20]
# **************************Data Spliting***************************
# 6 of Full Spatial Sequence for 2015213 :
# [9, 17, 18, 20, 29, 40]
# **************************Data Spliting***************************
# Spliting Rate:  0.8
# 4 of Dataset1:  [20 40 18  9]
# 2 of Dataset2:  [17 29]
# **************************Data Spliting***************************
# **************************Data Spliting***************************
# Spliting Rate:  0.9
# 3 of Dataset1:  [20 40 18]
# 1 of Dataset2:  [9]
# **************************Data Spliting***************************
# 1 of Full Spatial Sequence for 2015216 :
# [9]
# **************************Data Spliting***************************
# Spliting Rate:  0.8
# 0 of Dataset1:  []
# 1 of Dataset2:  [9]
# **************************Data Spliting***************************
# **************************Data Spliting***************************
# Spliting Rate:  0.9
# 0 of Dataset1:  []
# 0 of Dataset2:  []
# **************************Data Spliting***************************
# 4 of Full Spatial Sequence for 2015221 :
# [15, 18, 20, 41]
# **************************Data Spliting***************************
# Spliting Rate:  0.8
# 3 of Dataset1:  [18 15 20]
# 1 of Dataset2:  [41]
# **************************Data Spliting***************************
# **************************Data Spliting***************************
# Spliting Rate:  0.9
# 2 of Dataset1:  [20 15]
# 1 of Dataset2:  [18]
# **************************Data Spliting***************************
# 19 of Full Spatial Sequence for 2015226 :
# [9, 10, 15, 16, 17, 18, 20, 26, 27, 29, 31, 32, 33, 40, 41, 43, 44, 45, 51]
# **************************Data Spliting***************************
# Spliting Rate:  0.8
# 15 of Dataset1:  [41 10 45 44 29 20 18 31 15 40  9 32 33 26 51]
# 4 of Dataset2:  [16 17 27 43]
# **************************Data Spliting***************************
# **************************Data Spliting***************************
# Spliting Rate:  0.9
# 13 of Dataset1:  [18  9 26 32 15 45 29 51 31 44 10 20 33]
# 2 of Dataset2:  [40 41]
# **************************Data Spliting***************************
# 14 of Full Spatial Sequence for 2015229 :
# [9, 10, 17, 18, 20, 26, 27, 29, 31, 32, 33, 40, 43, 45]
# **************************Data Spliting***************************
# Spliting Rate:  0.8
# 11 of Dataset1:  [ 9 10 26 33 43 27 17 32 45 20 31]
# 3 of Dataset2:  [18 29 40]
# **************************Data Spliting***************************
# **************************Data Spliting***************************
# Spliting Rate:  0.9
# 9 of Dataset1:  [20 43 10 27 17 45  9 31 33]
# 2 of Dataset2:  [26 32]
# **************************Data Spliting***************************
# 5 of Full Spatial Sequence for 2015232 :
# [18, 29, 40, 43, 44]
# **************************Data Spliting***************************
# Spliting Rate:  0.8
# 4 of Dataset1:  [29 43 44 18]
# 1 of Dataset2:  [40]
# **************************Data Spliting***************************
# **************************Data Spliting***************************
# Spliting Rate:  0.9
# 3 of Dataset1:  [29 43 18]
# 1 of Dataset2:  [44]
# **************************Data Spliting***************************
# 3 of Full Spatial Sequence for 2015234 :
# [9, 17, 45]
# **************************Data Spliting***************************
# Spliting Rate:  0.8
# 2 of Dataset1:  [45  9]
# 1 of Dataset2:  [17]
# **************************Data Spliting***************************
# **************************Data Spliting***************************
# Spliting Rate:  0.9
# 1 of Dataset1:  [45]
# 1 of Dataset2:  [9]
# **************************Data Spliting***************************
# 19 of Full Spatial Sequence for 2015235 :
# [9, 10, 15, 16, 17, 18, 20, 26, 27, 29, 31, 32, 33, 40, 41, 43, 44, 45, 51]
# **************************Data Spliting***************************
# Spliting Rate:  0.8
# 15 of Dataset1:  [45 15 32 43 20 18 17 51 26 10 41 44  9 40 33]
# 4 of Dataset2:  [16 27 29 31]
# **************************Data Spliting***************************
# **************************Data Spliting***************************
# Spliting Rate:  0.9
# 13 of Dataset1:  [20 40 18 41 33 10 45 43  9 17 26 51 15]
# 2 of Dataset2:  [32 44]
# **************************Data Spliting***************************
# 1 of Full Spatial Sequence for 2015259 :
# [40]
# **************************Data Spliting***************************
# Spliting Rate:  0.8
# 0 of Dataset1:  []
# 1 of Dataset2:  [40]
# **************************Data Spliting***************************
# **************************Data Spliting***************************
# Spliting Rate:  0.9
# 0 of Dataset1:  []
# 0 of Dataset2:  []
# **************************Data Spliting***************************
# 6 of Full Spatial Sequence for 2015267 :
# [9, 15, 17, 18, 20, 26]
# **************************Data Spliting***************************
# Spliting Rate:  0.8
# 4 of Dataset1:  [20 15  9 26]
# 2 of Dataset2:  [17 18]
# **************************Data Spliting***************************
# **************************Data Spliting***************************
# Spliting Rate:  0.9
# 3 of Dataset1:  [20  9 26]
# 1 of Dataset2:  [15]
# **************************Data Spliting***************************
# 3 of Full Spatial Sequence for 2015272 :
# [9, 15, 45]
# **************************Data Spliting***************************
# Spliting Rate:  0.8
# 2 of Dataset1:  [15 45]
# 1 of Dataset2:  [9]
# **************************Data Spliting***************************
# **************************Data Spliting***************************
# Spliting Rate:  0.9
# 1 of Dataset1:  [45]
# 1 of Dataset2:  [15]
# **************************Data Spliting***************************
# 11 of Full Spatial Sequence for 2015275 :
# [9, 10, 15, 17, 18, 20, 26, 27, 31, 32, 44]
# **************************Data Spliting***************************
# Spliting Rate:  0.8
# 8 of Dataset1:  [18 32  9 10 20 27 26 17]
# 3 of Dataset2:  [15 31 44]
# **************************Data Spliting***************************
# **************************Data Spliting***************************
# Spliting Rate:  0.9
# 7 of Dataset1:  [17 18 20 32 27  9 10]
# 1 of Dataset2:  [26]
# **************************Data Spliting***************************
# 8 of Full Spatial Sequence for 2015277 :
# [9, 10, 17, 18, 33, 43, 44, 51]
# **************************Data Spliting***************************
# Spliting Rate:  0.8
# 6 of Dataset1:  [18 10 43  9 44 33]
# 2 of Dataset2:  [17 51]
# **************************Data Spliting***************************
# **************************Data Spliting***************************
# Spliting Rate:  0.9
# 5 of Dataset1:  [44  9 33 43 10]
# 1 of Dataset2:  [18]
# **************************Data Spliting***************************
# 4 of Full Spatial Sequence for 2015280 :
# [10, 31, 32, 33]
# **************************Data Spliting***************************
# Spliting Rate:  0.8
# 3 of Dataset1:  [33 31 32]
# 1 of Dataset2:  [10]
# **************************Data Spliting***************************
# **************************Data Spliting***************************
# Spliting Rate:  0.9
# 2 of Dataset1:  [32 31]
# 1 of Dataset2:  [33]
# **************************Data Spliting***************************
# 19 of Full Spatial Sequence for 2015282 :
# [9, 10, 15, 16, 17, 18, 20, 26, 27, 29, 31, 32, 33, 40, 41, 43, 44, 45, 51]
# **************************Data Spliting***************************
# Spliting Rate:  0.8
# 15 of Dataset1:  [16 45 43 27 10 51 44 33 29 41 15 20 17 26  9]
# 4 of Dataset2:  [18 31 32 40]
# **************************Data Spliting***************************
# **************************Data Spliting***************************
# Spliting Rate:  0.9
# 13 of Dataset1:  [17 44  9 33 26 15 10 45 27 41 51 43 20]
# 2 of Dataset2:  [16 29]
# **************************Data Spliting***************************
# 8 of Full Spatial Sequence for 2015283 :
# [15, 16, 26, 27, 29, 43, 44, 51]
# **************************Data Spliting***************************
# Spliting Rate:  0.8
# 6 of Dataset1:  [43 51 26 27 16 29]
# 2 of Dataset2:  [15 44]
# **************************Data Spliting***************************
# **************************Data Spliting***************************
# Spliting Rate:  0.9
# 5 of Dataset1:  [16 43 26 27 29]
# 1 of Dataset2:  [51]
# **************************Data Spliting***************************
# 3 of Full Spatial Sequence for 2015285 :
# [9, 10, 15]
# **************************Data Spliting***************************
# Spliting Rate:  0.8
# 2 of Dataset1:  [10 15]
# 1 of Dataset2:  [9]
# **************************Data Spliting***************************
# **************************Data Spliting***************************
# Spliting Rate:  0.9
# 1 of Dataset1:  [15]
# 1 of Dataset2:  [10]
# **************************Data Spliting***************************
# 19 of Full Spatial Sequence for 2015288 :
# [9, 10, 15, 16, 17, 18, 20, 26, 27, 29, 31, 32, 33, 40, 41, 43, 44, 45, 51]
# **************************Data Spliting***************************
# Spliting Rate:  0.8
# 15 of Dataset1:  [51 33 26 20 41 45 17 15 44  9 16 31 43 27 29]
# 4 of Dataset2:  [10 18 32 40]
# **************************Data Spliting***************************
# **************************Data Spliting***************************
# Spliting Rate:  0.9
# 13 of Dataset1:  [29 41 51 26 15 27 44 17 31 16  9 33 45]
# 2 of Dataset2:  [20 43]
# **************************Data Spliting***************************
# 18 of Full Spatial Sequence for 2015290 :
# [9, 10, 15, 16, 17, 18, 20, 26, 27, 29, 31, 32, 33, 40, 41, 43, 44, 45]
# **************************Data Spliting***************************
# Spliting Rate:  0.8
# 14 of Dataset1:  [26 15 29 31 32 17 43  9 40 16 27 33 45 18]
# 4 of Dataset2:  [10 20 41 44]
# **************************Data Spliting***************************
# **************************Data Spliting***************************
# Spliting Rate:  0.9
# 12 of Dataset1:  [27 33  9 15 17 43 32 26 31 16 29 18]
# 2 of Dataset2:  [40 45]
# **************************Data Spliting***************************
# 16 of Full Spatial Sequence for 2015291 :
# [9, 15, 17, 20, 26, 27, 29, 31, 32, 33, 40, 41, 43, 44, 45, 51]
# **************************Data Spliting***************************
# Spliting Rate:  0.8
# 12 of Dataset1:  [43 32 29 26  9 31 41 44 17 15 20 51]
# 4 of Dataset2:  [27 33 40 45]
# **************************Data Spliting***************************
# **************************Data Spliting***************************
# Spliting Rate:  0.9
# 10 of Dataset1:  [43 41 31  9 20 15 32 17 51 26]
# 2 of Dataset2:  [29 44]
# **************************Data Spliting***************************
# 1 of Full Spatial Sequence for 2015296 :
# [26]
# **************************Data Spliting***************************
# Spliting Rate:  0.8
# 0 of Dataset1:  []
# 1 of Dataset2:  [26]
# **************************Data Spliting***************************
# **************************Data Spliting***************************
# Spliting Rate:  0.9
# 0 of Dataset1:  []
# 0 of Dataset2:  []
# **************************Data Spliting***************************
# 19 of Full Spatial Sequence for 2015330 :
# [9, 10, 15, 16, 17, 18, 20, 26, 27, 29, 31, 32, 33, 40, 41, 43, 44, 45, 51]
# **************************Data Spliting***************************
# Spliting Rate:  0.8
# 15 of Dataset1:  [17 16 15 10 41 27 33 20 18 29 44 45 32 40 43]
# 4 of Dataset2:  [ 9 26 31 51]
# **************************Data Spliting***************************
# **************************Data Spliting***************************
# Spliting Rate:  0.9
# 13 of Dataset1:  [10 43 32 17 40 41 44 29 20 33 16 27 45]
# 2 of Dataset2:  [15 18]
# **************************Data Spliting***************************
# 19 of Full Spatial Sequence for 2015333 :
# [9, 10, 15, 16, 17, 18, 20, 26, 27, 29, 31, 32, 33, 40, 41, 43, 44, 45, 51]
# **************************Data Spliting***************************
# Spliting Rate:  0.8
# 15 of Dataset1:  [51 41 33 18 44 16 26 27 43 45 29 40 20 31 10]
# 4 of Dataset2:  [ 9 15 17 32]
# **************************Data Spliting***************************
# **************************Data Spliting***************************
# Spliting Rate:  0.9
# 13 of Dataset1:  [16 43 31 20 41 29 51 27 45 40 26 44 33]
# 2 of Dataset2:  [10 18]
# **************************Data Spliting***************************

# %%
# Initialize the dataset
train_dataset = SMAPDataset(config['root'], train_sequence)
valid_dataset = SMAPDataset(config['root'], valid_sequence)
test_dataset = SMAPDataset(config['root'], test_sequence)

# 选择标签值为大于0的样本作为训练集
train_indices = [i for i in range(len(train_dataset)) if 0 not in [x[0] for x in train_dataset[i]['label_data']]]
train_subset = Subset(train_dataset, train_indices)
valid_indices = [i for i in range(len(valid_dataset)) if 0 not in [x[0] for x in valid_dataset[i]['label_data']]]
valid_subset = Subset(valid_dataset, valid_indices)

# Pytorch data loader loads pytorch dataset into batches.
train_loader = DataLoader(train_subset, batch_size=config['train_batch_size'], shuffle=True, pin_memory=True, collate_fn=collate_fn, drop_last=True)
valid_loader = DataLoader(valid_subset, batch_size=config['valid_batch_size'], shuffle=True, pin_memory=True, collate_fn=collate_fn, drop_last=False)
test_loader = DataLoader(test_dataset, batch_size=config['test_batch_size'], shuffle=False, pin_memory=True, collate_fn=collate_fn, drop_last=False)
# Out:
# ***************************Load data path******************************
# _______________________________2015104_______________________________
# _____________________________smap cell: 17_____________________________
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\INPUT\SMAP\2015104\17.npy
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\INPUT\TEXTURE\17.npy
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\LABEL\SM\2015104\18.npy
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\LABEL\ATI\2015104\18.npy
# _____________________________smap cell: 18_____________________________
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\INPUT\SMAP\2015104\18.npy
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\INPUT\TEXTURE\18.npy
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\LABEL\SM\2
____________________________
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\INPUT\SMAP\2015290\10.npy
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\INPUT\TEXTURE\10.npy
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\LABEL\SM\2015290\16.npy
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\LABEL\ATI\2015290\16.npy
# _____________________________smap cell: 20_____________________________
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\INPUT\SMAP\2015290\20.npy
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\INPUT\TEXTURE\20.npy
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\LABEL\SM\2015290\27.npy
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\LABEL\ATI\2015290\27.npy
# _____________________________smap cell: 41_____________________________
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\INPUT\SMAP\2015290\41.npy
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\INPUT\TEXTURE\41.npy
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\LABEL\SM\2015290\6.npy
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\LABEL\ATI\2015290\6.npy
# _____________________________smap cell: 44_____________________________
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\INPUT\SMAP\2015290\44.npy
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\INPUT\TEXTURE\44.npy
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\LABEL\SM\2015290\11.npy
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\LABEL\ATI\2015290\11.npy
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\LABEL\SM\2015290\42.npy
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\LABEL\ATI\2015290\42.npy
# _______________________________2015291_______________________________
# _____________________________smap cell: 27_____________________________
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\INPUT\SMAP\2015291\27.npy
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\INPUT\TEXTURE\27.npy
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\LABEL\SM\2015291\12.npy
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\LABEL\ATI\2015291\12.npy
# _____________________________smap cell: 33_____________________________
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\INPUT\SMAP\2015291\33.npy
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\INPUT\TEXTURE\33.npy
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\LABEL\SM\2015291\32.npy
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\LABEL\ATI\2015291\32.npy
# _____________________________smap cell: 40_____________________________
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\INPUT\SMAP\2015291\40.npy
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\INPUT\TEXTURE\40.npy
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\LABEL\SM\2015291\35.npy
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\LABEL\ATI\2015291\35.npy
# _____________________________smap cell: 45_____________________________
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\INPUT\SMAP\2015291\45.npy
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\INPUT\TEXTURE\45.npy
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\LABEL\SM\2015291\37.npy
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\LABEL\ATI\2015291\37.npy
# _______________________________2015296_______________________________
# _____________________________smap cell: 26_____________________________
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\INPUT\SMAP\2015296\26.npy
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\INPUT\TEXTURE\26.npy
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\LABEL\SM\2015296\40.npy
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\LABEL\ATI\2015296\40.npy
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\LABEL\SM\2015296\25.npy
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\LABEL\ATI\2015296\25.npy
# _______________________________2015330_______________________________
# _____________________________smap cell: 9_____________________________
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\INPUT\SMAP\2015330\9.npy
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\INPUT\TEXTURE\9.npy
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\LABEL\SM\2015330\55.npy
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\LABEL\ATI\2015330\55.npy
# _____________________________smap cell: 26_____________________________
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\INPUT\SMAP\2015330\26.npy
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\INPUT\TEXTURE\26.npy
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\LABEL\SM\2015330\40.npy
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\LABEL\ATI\2015330\40.npy
# _____________________________smap cell: 31_____________________________
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\INPUT\SMAP\2015330\31.npy
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\INPUT\TEXTURE\31.npy
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\LABEL\SM\2015330\10.npy
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\LABEL\ATI\2015330\10.npy
# _____________________________smap cell: 51_____________________________
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\INPUT\SMAP\2015330\51.npy
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\INPUT\TEXTURE\51.npy
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\LABEL\SM\2015330\33.npy
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\LABEL\ATI\2015330\33.npy
# _______________________________2015333_______________________________
# _____________________________smap cell: 9_____________________________
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\INPUT\SMAP\2015333\9.npy
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\INPUT\TEXTURE\9.npy
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\LABEL\SM\2015333\55.npy
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\LABEL\ATI\2015333\55.npy
# _____________________________smap cell: 15_____________________________
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\INPUT\SMAP\2015333\15.npy
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\INPUT\TEXTURE\15.npy
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\LABEL\SM\2015333\4.npy
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\LABEL\ATI\2015333\4.npy
# _____________________________smap cell: 17_____________________________
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\INPUT\SMAP\2015333\17.npy
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\INPUT\TEXTURE\17.npy
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\LABEL\SM\2015333\18.npy
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\LABEL\ATI\2015333\18.npy
# _____________________________smap cell: 32_____________________________
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\INPUT\SMAP\2015333\32.npy
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\INPUT\TEXTURE\32.npy
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\LABEL\SM\2015333\54.npy
# D:\1GRADUATED\paper\downscaling_data\Soil_moisture_downscale_czt\DATASET\SD\LABEL\ATI\2015333\54.npy

# %%
print(train_dataset.__len__())
print(valid_dataset.__len__())
print(test_dataset.__len__())
# Out:
# 251
# 56
# 102

# %% [markdown]
# # Data visualization

# %%
import matplotlib.pyplot as plt

# %%
def display_data_spatial_distribution(full_smapid_sequence, dict_sequence, data_name, root, seed):
    # 创建一个空数组
    bg_scale = -10
    z_scale = -5
    verified_mat = np.ones((7,13))
    verified_mat = verified_mat * bg_scale
    verified_mat[0][2:7] = z_scale
    verified_mat[1][0:8] = z_scale
    verified_mat[2][0:10] = z_scale
    verified_mat[3][0:12] = z_scale
    verified_mat[4][2:13] = z_scale
    verified_mat[5][6:13] = z_scale
    verified_mat[6][7:12] = z_scale
    row_i = np.where(verified_mat!=bg_scale)[0]
    col_j = np.where(verified_mat!=bg_scale)[1]
    
    # 确定cell数据量的大小
    for smapid in full_smapid_sequence:
        y = [key for key, value in dict_sequence.items() if smapid in value]
        verified_mat[row_i[smapid]][col_j[smapid]] = len(y)

    plt.figure(figsize=(13,7))
    plt.imshow(verified_mat, alpha=0.8, extent=[0, 13, 0, 7], vmin=-10, vmax=20, cmap='coolwarm')
    
    # 设置图形标题
    plt.title('Number of {} Data in Each Cell'.format(data_name))
    plt.xticks(range(14))
    plt.grid(True)
    plt.colorbar()
    
#     # 显示图形
#     plt.savefig(root + 'OUTPUT\\IMAGE\\DATAVISUALIZE\\CNN\\' + str(seed) + '\\' + data_name + 'DataSpatialDistribution.png', dpi=600, transparent=False)    
#     plt.show()

# %%
train_full_smapid_sequence = train_dataset.get_full_smapid_sequence()
valid_full_smapid_sequence = valid_dataset.get_full_smapid_sequence()
test_full_smapid_sequence = test_dataset.get_full_smapid_sequence()

display_data_spatial_distribution(train_full_smapid_sequence, train_sequence, 'Train', config['root'], config['seed'])
display_data_spatial_distribution(valid_full_smapid_sequence, valid_sequence, 'Valid', config['root'], config['seed'])
display_data_spatial_distribution(test_full_smapid_sequence, test_sequence, 'Test', config['root'], config['seed'])

# %%
def display_data_temporal_distribution(full_smapid_sequence, dict_sequence, data_name, root, seed):
    # 绘制散点图
    plt.figure(figsize=(6, 3))

    X = range(len(full_smapid_sequence))
    for i, smapid in enumerate(full_smapid_sequence):
        y = [int(key.split('2015')[1]) for key, value in dict_sequence.items() if smapid in value]
        x = [i] * len(y)  # 重复 X 坐标以便绘制多个散点
        plt.scatter(x, y)

    # 设置图形标题和坐标轴标签
    plt.title(data_name + ' Time Sequence Distribution for Each SMAP Cell')
    plt.xlabel("SMAPID")
    plt.ylabel("Day")
    plt.xticks(X, list(full_smapid_sequence))
    plt.yticks(np.arange(90, 360, 20))

#     # 显示图形
#     plt.savefig(root + 'OUTPUT\\IMAGE\\DATAVISUALIZE\\CNN\\' + str(seed) + '\\' + data_name + 'DataTemporalDistribution.png', dpi=600, transparent=False)    
#     plt.show()

# %%
train_full_smapid_sequence = train_dataset.get_full_smapid_sequence()
valid_full_smapid_sequence = valid_dataset.get_full_smapid_sequence()
test_full_smapid_sequence = test_dataset.get_full_smapid_sequence()

display_data_temporal_distribution(train_full_smapid_sequence, train_sequence, 'Train', config['root'], config['seed'])
display_data_temporal_distribution(valid_full_smapid_sequence, valid_sequence, 'Valid', config['root'], config['seed'])
display_data_temporal_distribution(test_full_smapid_sequence, test_sequence, 'Test', config['root'], config['seed'])

# %% [markdown]
# # Start training!

# %%
def trainer(train_loader, valid_loader, model, config, device):

    criterion = self_defined_loss 
    optimizer = torch.optim.SGD(model.parameters(), lr=config['learning_rate'], momentum=config['momentum']) 
    
    # learning rate decay
#     ExpLR = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.98)
#     MultiStepLR = torch.optim.lr_scheduler.MultiStepLR(optimizer_MultiStepLR,
#                     milestones=[200, 300, 320, 340, 200], gamma=0.8)
#     CosineLR = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer_CosineLR, T_max=150, eta_min=0)
    RLRP = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=config['gamma'], patience=config['step_size'], threshold=0.03)
#     StepLR = torch.optim.lr_scheduler.StepLR(optimizer, step_size=config['step_size'], gamma=config['gamma'])

    
    if not os.path.isdir(config['root'] + '\\OUTPUT\\MODELS\\'):
        os.mkdir(config['root'] + '\\OUTPUT\\MODELS\\') # Create directory of saving models.

    n_epochs, best_loss, step, early_stop_count = config['n_epochs'], math.inf, 0, 0

    for epoch in range(n_epochs):
        model.train() # Set your model to train mode.
        
        loss_record = []
        physical_loss_record = []
        eds_loss_record = []
        for data_pkg in train_loader:
            x = data_pkg['processed_data']
            optimizer.zero_grad()               # Set gradient to zero.
            pred = model(x)
#             x, pred = x.to(device), pred.to(device)   # Move your data to device. 
            
            physical_loss, eds_loss = criterion(pred, data_pkg['label_data'], config['train_batch_size'], config['eds_lambda'], 'Training')
            loss = physical_loss + eds_loss
            loss.backward()                     # Compute gradient(backpropagation).
            optimizer.step()                    # Update parameters.
            step += 1
            loss_record.append(loss.detach().item())
            physical_loss_record.append(physical_loss.detach().item())
            eds_loss_record.append(eds_loss.detach().item())
            
        mean_train_physical_loss = sum(physical_loss_record)/len(physical_loss_record)
        mean_train_eds_loss = sum(eds_loss_record)/len(eds_loss_record)
        mean_train_loss = sum(loss_record)/len(loss_record)
        
        model.eval() # Set your model to evaluation mode.
        loss_record = []
        physical_loss_record = []
        eds_loss_record = []
        for data_pkg in valid_loader:
            x = data_pkg['processed_data']
            with torch.no_grad():
                pred = model(x)
#                 print(data_pkg['label_data'])
#             x, pred = x.to(device), pred.to(device)   # Move your data to device. 
                physical_loss, eds_loss = criterion(pred, data_pkg['label_data'], config['train_batch_size'], config['eds_lambda'], 'Validing')
                loss = physical_loss + eds_loss
        
            loss_record.append(loss.item())
            physical_loss_record.append(physical_loss.item())
            eds_loss_record.append(eds_loss.item())
        
        print(loss_record)
        mean_valid_loss = sum(loss_record)/len(loss_record)
        mean_valid_eds_loss = sum(eds_loss_record)/len(eds_loss_record)
        mean_valid_physical_loss = sum(physical_loss_record)/len(physical_loss_record)
        
        current_lr = (optimizer.param_groups[0])['lr']
        print(f'Epoch [{epoch+1}/{n_epochs}] (LR: {current_lr}):')
        print(f'Train loss: {mean_train_loss:.4f} || Train physical loss: {mean_train_physical_loss:.4f} || Train eds loss: {mean_train_eds_loss:.4f}')
        print(f'Valid loss: {mean_valid_loss:.4f} || Valid physical loss: {mean_valid_physical_loss:.4f} || Valid eds loss: {mean_valid_eds_loss:.4f}')
         
        if mean_valid_loss < best_loss:
            best_loss = mean_valid_loss
            _name = str(best_loss)
            _name = 'output'
            torch.save(model.state_dict(), config['root'] + '\\OUTPUT\\MODELS\\CNN\\' + _name + '.ckpt') # Save your best model
            print('Saving model with loss {:.3f}...'.format(best_loss))
            early_stop_count = 0
        else: 
            early_stop_count += 1

        if early_stop_count >= config['early_stop']:
            print('\nModel is not improving, so we halt the training session.')
            _name = str(best_loss)
            _name = 'output'
            torch.save(model.state_dict(), config['root'] + '\\OUTPUT\\MODELS\\CNN\\' + _name + '.ckpt') # Save your best model
            return
        #         StepLR.step()
        RLRP.step(mean_valid_loss)

# %%
if config['is_train']==True:
    print(train_dataset.get_input_shape(0))
    model = SMCNN(input_channel=train_dataset.get_input_shape(0)[2]).to(device) # put your model and data on the same computation device.
    print(model)
    trainer(train_loader, valid_loader, model, config, device)
# Out:
# (11, 11, 19)
# SMCNN(
#   (cnn): Sequential(
#     (0): Conv2d(19, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#   )
#   (fc): Sequential(
#     (0): Linear(in_features=3872, out_features=4, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=4, out_features=1, bias=True)
#   )
# )
# sd_pred: tensor([ 0.2197,  0.1796,  0.1799,  0.0149,  0.1450,  0.1451,  0.0230,  0.0412,
#          0.1448,  0.0029,  0.0070, -0.0053,  0.0069,  0.0073,  0.1043,  0.0095,
#          0.0070,  0.2685,  0.2199,  0.2682,  0.0072,  0.0008,  0.1043,  0.0071,
#          0.2210, -0.0053,  0.1791,  0.0413,  0.0996, -0.0053,  0.2194,  0.0412,
#          0.1451,  0.0285,  0.2680,  0.0283,  0.0285,  0.0997,  0.0671])
# [4.153777122497559]
# Epoch [1/5000] (LR: 0.005):
# Train loss: 4.9295 || Train physical loss: 0.1907 || Train eds loss: 4.7388
# Valid loss: 4.1538 || Valid physical loss: 0.0404 || Valid eds loss: 4.1133
# Saving model with loss 4.154...
# sd_pred: tensor([ 3.4153, 12.4706,  3.4161,  9.7778,  2.5578,  9.7790,  5.2386,  2.3528,
#         10.7349,  3.2589, 10.7152,  4.0015,  3.4083,  7.4607,  5.2431,  9.7702,
#         10.7288, 12.4821,  7.4608,  2.5794,  2.5679,  2.5897,  2.3537,  2.8666,
#         12.3769,  2.5801,  2.9375,  9.7765, 12.4733,  2.6067,  3.2512,  2.5729,
#         10.2538,  2.8195,  3.2518, 10.2620,  2.3496,  2.5728, 10.2661])
# [31.89170265197754]
# Epoch [2/5000] (LR: 0.005):
# Train loss: 3.3413 || Train physical loss: 0.3994 || Train eds loss: 2.9420
# Valid loss: 31.8917 || Valid physical loss: 31.7070 || Valid eds loss: 0.1847
# sd_pred: tensor([164.8422, 194.8637, 201.5705, 163.6024, 178.6901, 179.6846, 201.5765,
#         180.0118, 165.4068, 179.6791, 164.8319, 172.8607, 201.5509, 178.6971,
#         179.6974, 178.7018, 164.8331, 153.9115, 153.9123, 194.8726, 188.9404,
#         178.6971, 163.6093, 179.3393, 188.9647, 153.9025, 172.9566, 188.9296,
#         178.6908, 168.0895, 179.6817, 194.8901, 178.6809, 172.9605, 194.2168,
#         172.9556, 173.3162, 180.0116, 165.5026])
# [27403.69140625]
# Epoch [3/5000] (LR: 0.005):
# Train loss: 143.5183 || Train physical loss: 141.2392 || Train eds loss: 2.2791
# Valid loss: 27403.6914 || Valid physical loss: 27403.6719 || Valid eds loss: 0.0203
# sd_pred: tensor([-101.8737, -101.8737, -101.8737, -101.8737, -101.8737, -101.8737,
#         -101.8737, -101.8737, -101.8737, -101.8737, -101.8737, -101.8737,
#         -101.8737, -101.8737, -101.8737, -101.8737, -101.8737, -101.8737,
#         -101.8737, -101.8737, -101.8737, -101.8737, -101.8737, -101.8737,
#         -101.8737, -101.8737, -101.8737, -101.8737, -101.8737, -101.8737,
#         -101.8737, -101.8737, -101.8737, -101.8737, -101.8737, -101.8737,
#         -101.8737, -101.8737, -101.8737])
# [9310.6328125]
# Epoch [4/5000] (LR: 0.005):
# Train loss: 24850.8875 || Train physical loss: 24847.2808 || Train eds loss: 3.6061
# Valid loss: 9310.6328 || Valid physical loss: 9305.6328 || Valid eds loss: 5.0000
# sd_pred: tensor([-155.5453, -155.5453, -155.5453, -155.5453, -155.5453, -155.5453,
#         -155.5453, -155.5453, -155.5453, -155.5453, -155.5453, -155.5453,
#         -155.5453, -155.5453, -155.5453, -155.5453, -155.5453, -155.5453,
#         37172.1289, 37172.1289, 37172.1289, 37172.1289, 37172.1289, 37172.1289,
#         37172.1289, 37172.1289, 37172.1289, 37172.1289, 37172.1289, 37172.1289,
#         37172.1289, 37172.1289, 37172.1289, 37172.1289, 37172.1289, 37172.1289,
#         37172.1289, 37172.1289, 37172.1289, 37172.1289, 37172.1289, 37172.1289,
#         37172.1289, 37172.1289, 37172.1289])
# [1239995648.0]
# Epoch [9/5000] (LR: 0.005):
# Train loss: 10383146834.6667 || Train physical loss: 10383146832.0000 || Train eds loss: 5.0000
# Valid loss: 1239995648.0000 || Valid physical loss: 1239995648.0000 || Valid eds loss: 5.0000
# sd_pred: tensor([-164618.6875, -164618.6875, -164618.6875, -164618.6875, -164618.6875,
#         -164618.6875, -164618.6875, -164618.6875, -164618.6875, -164618.6875,
#         -164618.6875, -164618.6875, -164618.6875, -164618.6875, -164618.6875,
#         -164618.6875, -164618.6875, -164618.6875, -164618.6875, -164618.6875,
#         -164618.6875, -164618.6875, -164618.6875, -164618.6875, -164618.6875,
#         -164618.6875, -164618.6875, -164618.6875, -164618.6875, -164618.6875,
#         -164618.6875, -164618.6875, -164618.6875, -164618.6875, -164618.6875,
#         -164618.6875, -164618.6875, -164618.6875, -164618.6875])
# [24318818304.0]
# Epoch [10/5000] (LR: 0.005):
# Train loss: 125244412586.6667 || Train physical loss: 125244412586.6667 || Train eds loss: 5.0000
# Valid loss: 24318818304.0000 || Valid physical loss: 24318818304.0000 || Valid eds loss: 5.0000
# sd_pred: tensor([769184.7500, 769184.7500, 769184.7500, 769184.7500, 769184.7500,
#         769184.7500, 769184.7500, 769184.7500, 769184.7500, 769184.7500,
#         769184.7500, 769184.7500, 769184.7500, 769184.7500, 769184.7500,
#         769184.7500, 769184.7500, 769184.7500, 769184.7500, 769184.7500,
#         769184.7500, 769184.7500, 769184.7500, 769184.7500, 769184.7500,
#         769184.7500, 769184.7500, 769184.7500, 769184.7500, 769184.7500,
#         769184.7500, 769184.7500, 769184.7500, 769184.7500, 769184.7500,
#         769184.7500, 769184.7500, 769184.7500, 769184.7500])
# [530940329984.0]
# Epoch [11/5000] (LR: 0.005):
# Train loss: 4091470962688.0000 || Train physical loss: 4091470962688.0000 || Train eds loss: 5.0000
# Valid loss: 530940329984.0000 || Valid physical loss: 530940329984.0000 || Valid eds loss: 5.0000
# sd_pred: tensor([1821251.2500, 1821251.2500, 1821251.2500, 1821251.2500, 1821251.2500,
#         1821251.2500, 1821251.2500, 1821251.2500, 1821251.2500, 1821251.2500,
#         1821251.2500, 1821251.2500, 1821251.2500, 1821251.2500, 1821251.2500,
#         1821251.2500, 1821251.2500, 1821251.2500, 1821251.2500, 1821251.2500,
#         1821251.2500, 1821251.2500, 1821251.2500, 1821251.2500, 1821251.2500,
#         1821251.2500, 1821251.2500, 1821251.2500, 1821251.2500, 1821251.2500,
#         1821251.2500, 1821251.2500, 1821251.2500, 1821251.2500, 1821251.2500,
#         1821251.2500, 1821251.2500, 1821251.2500, 1821251.2500])
# [2976624672768.0]
#         -1.6990e+11, -1.6990e+11, -1.6990e+11, -1.6990e+11, -1.6990e+11,
#         -1.6990e+11, -1.6990e+11, -1.6990e+11, -1.6990e+11, -1.6990e+11,
#         -1.6990e+11, -1.6990e+11, -1.6990e+11, -1.6990e+11, -1.6990e+11,
#         -1.6990e+11, -1.6990e+11, -1.6990e+11, -1.6990e+11, -1.6990e+11,
#         -1.6990e+11, -1.6990e+11, -1.6990e+11, -1.6990e+11])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9132/2639257196.py in <module>
#       3     model = SMCNN(input_channel=train_dataset.get_input_shape(0)[2]).to(device) # put your model and data on the same computation device.
#       4     print(model)
# ----> 5     trainer(train_loader, valid_loader, model, config, device)
#
# ~\AppData\Local\Temp/ipykernel_9132/2435509334.py in trainer(train_loader, valid_loader, model, config, device)
#      53 #                 print(data_pkg['label_data'])
#      54 #             x, pred = x.to(device), pred.to(device)   # Move your data to device.
# ---> 55                 physical_loss, eds_loss = criterion(pred, data_pkg['label_data'], config['train_batch_size'], config['eds_lambda'], 'Validing')
#      56                 loss = physical_loss + eds_loss
#      57
#
# D:\1GRADUATED\paper\ZResearch\downscaling\code\SM_Downscaling_Hybrid\CNN_learn_from_insitu_predict_sd\SDLoss.py in self_defined_loss(pred, label_data, batch_size, eds_lambda, flag)
#      25
#      26 def self_defined_loss(pred, label_data, batch_size, eds_lambda, flag):
# ---> 27     return physics_loss(pred, label_data, batch_size, flag), EDS_loss(pred, eds_lambda)
#      28
#      29 def physics_loss(pred, label_data, batch_size, flag):
#
# D:\1GRADUATED\paper\ZResearch\downscaling\code\SM_Downscaling_Hybrid\CNN_learn_from_insitu_predict_sd\SDLoss.py in physics_loss(pred, label_data, batch_size, flag)
#      51     if flag=='Validing':
#      52         print('sd_pred: {}'.format(pred))
# ---> 53         display(pred_list, sm_pred_list, sm_insitu_list, flag)
#      54 #     print('sm_pred: {}'.format(torch.FloatTensor(sm_pred_list)))
#      55 #     print('sm_insitu: {}'.format(torch.FloatTensor(sm_insitu_list)))
#
# D:\1GRADUATED\paper\ZResearch\downscaling\code\SM_Downscaling_Hybrid\CNN_learn_from_insitu_predict_sd\SDLoss.py in display(pred_list, sm_pred_list, sm_insitu_list, flag)
#      18
#      19     # display the plot
# ---> 20     plt.show()
#      21
#      22 def calculate_upscaling_sm(sm_bar, sm_bar_sd, ati, ati_bar, ati_bar_sd):
#
# ~\anaconda3\envs\datamining\lib\site-packages\matplotlib\pyplot.py in show(*args, **kwargs)
#     376     """
#     377     _warn_if_gui_out_of_main_thread()
# --> 378     return _backend_mod.show(*args, **kwargs)
#     379
#     380
#
# ~\anaconda3\envs\datamining\lib\site-packages\matplotlib_inline\backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
#      43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ~\anaconda3\envs\datamining\lib\site-packages\IPython\core\display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     318             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     319         else:
# --> 320             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     321             if not format_dict:
#     322                 # nothing to display (e.g. _ipython_display_ took over)
#
# ~\anaconda3\envs\datamining\lib\site-packages\IPython\core\formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# ~\anaconda3\envs\datamining\lib\site-packages\decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# ~\anaconda3\envs\datamining\lib\site-packages\IPython\core\formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~\anaconda3\envs\datamining\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~\anaconda3\envs\datamining\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
#
# ~\anaconda3\envs\datamining\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2232             if bbox_inches:
#    2233                 if bbox_inches == "tight":
# -> 2234                     bbox_inches = self.figure.get_tightbbox(
#    2235                         renderer, bbox_extra_artists=bbox_extra_artists)
#    2236                     if pad_inches is None:
#
# ~\anaconda3\envs\datamining\lib\site-packages\matplotlib\figure.py in get_tightbbox(self, renderer, bbox_extra_artists)
#    1637
#    1638         for a in artists:
# -> 1639             bbox = a.get_tightbbox(renderer)
#    1640             if bbox is not None and (bbox.width != 0 or bbox.height != 0):
#    1641                 bb.append(bbox)
#
# ~\anaconda3\envs\datamining\lib\site-packages\matplotlib\axes\_base.py in get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4428             if self.xaxis.get_visible():
#    4429                 try:
# -> 4430                     bb_xaxis = self.xaxis.get_tightbbox(
#    4431                         renderer, for_layout_only=for_layout_only)
#    4432                 except TypeError:
#
# ~\anaconda3\envs\datamining\lib\site-packages\matplotlib\axis.py in get_tightbbox(self, renderer, for_layout_only)
#    1084             return
#    1085
# -> 1086         ticks_to_draw = self._update_ticks()
#    1087
#    1088         self._update_label_position(renderer)
#
# ~\anaconda3\envs\datamining\lib\site-packages\matplotlib\axis.py in _update_ticks(self)
#    1034             tick.set_label1(label)
#    1035             tick.set_label2(label)
# -> 1036         minor_locs = self.get_minorticklocs()
#    1037         minor_labels = self.minor.formatter.format_ticks(minor_locs)
#    1038         minor_ticks = self.get_minor_ticks(len(minor_locs))
#
# ~\anaconda3\envs\datamining\lib\site-packages\matplotlib\axis.py in get_minorticklocs(self)
#    1263         """Return this Axis' minor tick locations in data coordinates."""
#    1264         # Remove minor ticks duplicating major ticks.
# -> 1265         major_locs = self.major.locator()
#    1266         minor_locs = self.minor.locator()
#    1267         transform = self._scale.get_transform()
#
# ~\anaconda3\envs\datamining\lib\site-packages\matplotlib\ticker.py in __call__(self)
#    2262     def __call__(self):
#    2263         vmin, vmax = self.axis.get_view_interval()
# -> 2264         return self.tick_values(vmin, vmax)
#    2265
#    2266     def tick_values(self, vmin, vmax):
#
# ~\anaconda3\envs\datamining\lib\site-packages\matplotlib\ticker.py in tick_values(self, vmin, vmax)
#    2270         vmin, vmax = mtransforms.nonsingular(
#    2271             vmin, vmax, expander=1e-13, tiny=1e-14)
# -> 2272         locs = self._raw_ticks(vmin, vmax)
#    2273
#    2274         prune = self._prune
#
# ~\anaconda3\envs\datamining\lib\site-packages\matplotlib\ticker.py in _raw_ticks(self, vmin, vmax)
#    2209         if self._nbins == 'auto':
#    2210             if self.axis is not None:
# -> 2211                 nbins = np.clip(self.axis.get_tick_space(),
#    2212                                 max(1, self._min_n_ticks - 1), 9)
#    2213             else:
#
# ~\anaconda3\envs\datamining\lib\site-packages\matplotlib\axis.py in get_tick_space(self)
#    2268     def get_tick_space(self):
#    2269         ends = mtransforms.Bbox.from_bounds(0, 0, 1, 1)
# -> 2270         ends = ends.transformed(self.axes.transAxes -
#    2271                                 self.figure.dpi_scale_trans)
#    2272         length = ends.width * 72
#
# ~\anaconda3\envs\datamining\lib\site-packages\matplotlib\transforms.py in transformed(self, transform)
#     490         """
#     491         pts = self.get_points()
# --> 492         ll, ul, lr = transform.transform(np.array(
#     493             [pts[0], [pts[0, 0], pts[1, 1]], [pts[1, 0], pts[0, 1]]]))
#     494         return Bbox([ll, [lr[0], ul[1]]])
#
# ~\anaconda3\envs\datamining\lib\site-packages\matplotlib\transforms.py in transform(self, values)
#    1468
#    1469         # Transform the values
# -> 1470         res = self.transform_affine(self.transform_non_affine(values))
#    1471
#    1472         # Convert the result back to the shape of the input values.
#
# ~\anaconda3\envs\datamining\lib\site-packages\matplotlib\transforms.py in transform_affine(self, points)
#    2377     def transform_affine(self, points):
#    2378         # docstring inherited
# -> 2379         return self.get_affine().transform(points)
#    2380
#    2381     def transform_non_affine(self, points):
#
# ~\anaconda3\envs\datamining\lib\site-packages\matplotlib\transforms.py in get_affine(self)
#    2404             return self._b.get_affine()
#    2405         else:
# -> 2406             return Affine2D(np.dot(self._b.get_affine().get_matrix(),
#    2407                                    self._a.get_affine().get_matrix()))
#    2408
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Testing

# %%
def tester(test_loader, model, config, device):
    criterion = physics_loss # Define your loss function, do not modify this.
    model.eval() # Set your model to evaluation mode.
    loss_record = []
    pred_list = []
    for data_pkg in test_loader:
        x = data_pkg['processed_data']
#         x, y = x.to(device), y.to(device)   # Move your data to device. 
        with torch.no_grad():
            pred = model(x)
            loss = criterion(pred, data_pkg['label_data'], config['test_batch_size'], 'Testing')
        loss_record.append(loss.item())
        pred_list.append(pred.item())
    mean_test_loss = sum(loss_record)/len(loss_record)
    print(len(loss_record))
    print(mean_test_loss)
    for x in pred_list:
        print(x)
#     print(loss_record)  
    return loss_record, pred_list

# %%
param_path = os.path.join(config['root'],'OUTPUT\\MODELS\\CNN\\output.ckpt' )
model = SMCNN(input_channel=train_dataset.get_input_shape(0)[2]).to(device)
model.load_state_dict(torch.load(param_path))
loss_record, pred_list = tester(test_loader, model, config, device)

# %%
plt.plot(pred_list)
# 添加标题和标签
plt.title('Prediction of SM Standard Devation')
# plt.xlabel('Index of Model')
plt.ylabel('SM Standard Devation')

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# 将数据转换为DataFrame格式
df = pd.DataFrame(loss_record, columns=['MSE'])

# 绘制小提琴图
sns.violinplot(y='MSE', data=df, scale='count')
# sns.barplot(y='MSE', data=df)
# 添加标题和标签
plt.title('Distribution of MSE')
# plt.xlabel('Index of Model')
plt.ylabel('MSE Value')

# 显示图形
plt.savefig(config['root'] + 'OUTPUT\\IMAGE\\DATAVISUALIZE\\CNN\\' + str(config['seed']) + '\\' + 'MSEDistribution.png', dpi=600, transparent=False)    
plt.show()
